# %% [markdown]
# <a href="https://colab.research.google.com/github/chottokun/colaboratory/blob/main/codeinterpreterap.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q openai python-dotenv

# %%
import shutil
import os
import openai

# Google Driveをマウント
from google.colab import drive
drive.mount('/content/drive')

# Mount env direcroty
envfile_mount = '/content/drive/MyDrive/Colab Notebooks/env/'

# get secret
secrets_file_path = os.path.join(envfile_mount, 'env.txt')
shutil.copyfile(secrets_file_path, ".env")

# load env
from dotenv import load_dotenv
load_dotenv()

# just in the case...
openai.api_key = os.getenv("OPENAI_API_KEY")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install codeinterpreterapi > /dev/null

# %%
from codeinterpreterapi import CodeInterpreterSession

async with CodeInterpreterSession() as session:
    response = await session.generate_response(
      """
      Please consider the appropriate model for the following time series data and
      visualize the results.
      https://github.com/jbrownlee/Datasets/blob/master/airline-passengers.csv
      """
    )

    print("AI: ", response.content)
    for file in response.files:
        file.show_image()
# Out:
# INFO: Using a LocalBox which is not isolated.
#       This is only for testing and development.
#       Make sure to put an API-Key in production.
#
# AI:  The plot shows the original data (in blue), the predictions made by the model for the same time period as the original data (in red), and the forecast for the next 10 years (in green). The shaded areas represent the confidence intervals for the predictions and the forecast.
#
# As we can see, the model fits the original data quite well, capturing both the upward trend and the seasonal pattern. The forecast for the next 10 years suggests that the number of passengers will continue to increase, following the same trend and seasonal pattern.
#
# ...
